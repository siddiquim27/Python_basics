# %% [markdown]
# ## Pandas library

# %%
## pandas for cleaning data, exploring data and analyzing data

# %%
import pandas as pd

# %%
 df = pd.read_csv("C:/Users/Noman Siddiqui/Downloads/data1.csv")

# %%
df
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2023                     Level 1                99999
# 1      2023                     Level 1                99999
# 2      2023                     Level 1                99999
# 3      2023                     Level 1                99999
# 4      2023                     Level 1                99999
# ...     ...                         ...                  ...
# 50980  2013                     Level 3                 ZZ11
# 50981  2013                     Level 3                 ZZ11
# 50982  2013                     Level 3                 ZZ11
# 50983  2013                     Level 3                 ZZ11
# 50984  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
## top 5 data
df.head()
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0  2023                     Level 1                99999       All industries
# 1  2023                     Level 1                99999       All industries
# 2  2023                     Level 1                99999       All industries
# 3  2023                     Level 1                99999       All industries
# 4  2023                     Level 1                99999       All industries
#
#                 Units Variable_code  \
# 0  Dollars (millions)           H01
# 1  Dollars (millions)           H04
# 2  Dollars (millions)           H05
# 3  Dollars (millions)           H07
# 4  Dollars (millions)           H08
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# 1  Sales, government funding, grants and subsidies  Financial performance
# ...

# %%
## last 5 data
df.tail()
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 50980  2013                     Level 3                 ZZ11
# 50981  2013                     Level 3                 ZZ11
# 50982  2013                     Level 3                 ZZ11
# 50983  2013                     Level 3                 ZZ11
# 50984  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC       Units Variable_code  \
# 50980  Food product manufacturing  Percentage           H37
# 50981  Food product manufacturing  Percentage           H38
# 50982  Food product manufacturing  Percentage           H39
# 50983  Food product manufacturing  Percentage           H40
# 50984  Food product manufacturing  Percentage           H41
#
#                              Variable_name Variable_category Value  \
# 50980                          Quick ratio  Financial ratios    52
# 50981  Margin on sales of goods for resale  Financial ratios    40
# ...

# %%
df.dtypes
# Out:
# Year                            int64
# Industry_aggregation_NZSIOC    object
# Industry_code_NZSIOC           object
# Industry_name_NZSIOC           object
# Units                          object
# Variable_code                  object
# Variable_name                  object
# Variable_category              object
# Value                          object
# Industry_code_ANZSIC06         object
# dtype: object

# %%
df.describe() ## count mean and all
# Out:
#                Year
# count  50985.000000
# mean    2018.000000
# std        3.162309
# min     2013.000000
# 25%     2015.000000
# 50%     2018.000000
# 75%     2021.000000
# max     2023.000000

# %%
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2023                     Level 1                99999
# 1      2023                     Level 1                99999
# 2      2023                     Level 1                99999
# 3      2023                     Level 1                99999
# 4      2023                     Level 1                99999
# ...     ...                         ...                  ...
# 50980  2013                     Level 3                 ZZ11
# 50981  2013                     Level 3                 ZZ11
# 50982  2013                     Level 3                 ZZ11
# 50983  2013                     Level 3                 ZZ11
# 50984  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
## hamko jo jo row coloumn chaiye wo isse ajyga
df[['Year', 'Industry_code_NZSIOC', 'Units','Variable_code', 'Value', 'Industry_code_ANZSIC06']]
# Out:
#        Year Industry_code_NZSIOC               Units Variable_code   Value  \
# 0      2023                99999  Dollars (millions)           H01  930995
# 1      2023                99999  Dollars (millions)           H04  821630
# 2      2023                99999  Dollars (millions)           H05   84354
# 3      2023                99999  Dollars (millions)           H07   25010
# 4      2023                99999  Dollars (millions)           H08  832964
# ...     ...                  ...                 ...           ...     ...
# 50980  2013                 ZZ11          Percentage           H37      52
# 50981  2013                 ZZ11          Percentage           H38      40
# 50982  2013                 ZZ11          Percentage           H39      12
# 50983  2013                 ZZ11          Percentage           H40       5
# 50984  2013                 ZZ11          Percentage           H41      46
#
#                                   Industry_code_ANZSIC06
# ...

# %%
df.dtypes == 'object'
# Out:
# Year                           False
# Industry_aggregation_NZSIOC     True
# Industry_code_NZSIOC            True
# Industry_name_NZSIOC            True
# Units                           True
# Variable_code                   True
# Variable_name                   True
# Variable_category               True
# Value                           True
# Industry_code_ANZSIC06          True
# dtype: bool

# %%
df.dtypes == 'int64'
# Out:
# Year                            True
# Industry_aggregation_NZSIOC    False
# Industry_code_NZSIOC           False
# Industry_name_NZSIOC           False
# Units                          False
# Variable_code                  False
# Variable_name                  False
# Variable_category              False
# Value                          False
# Industry_code_ANZSIC06         False
# dtype: bool

# %%
df.dtypes == 'float64'
# Out:
# Year                           False
# Industry_aggregation_NZSIOC    False
# Industry_code_NZSIOC           False
# Industry_name_NZSIOC           False
# Units                          False
# Variable_code                  False
# Variable_name                  False
# Variable_category              False
# Value                          False
# Industry_code_ANZSIC06         False
# dtype: bool

# %%
df[df.dtypes[df.dtypes == 'object'].index]
# Out:
#       Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0                         Level 1                99999
# 1                         Level 1                99999
# 2                         Level 1                99999
# 3                         Level 1                99999
# 4                         Level 1                99999
# ...                           ...                  ...
# 50980                     Level 3                 ZZ11
# 50981                     Level 3                 ZZ11
# 50982                     Level 3                 ZZ11
# 50983                     Level 3                 ZZ11
# 50984                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# 2                  All industries  Dollars (millions)           H05
# ...

# %%
df[df.dtypes[df.dtypes == 'int64'].index]
# Out:
#        Year
# 0      2023
# 1      2023
# 2      2023
# 3      2023
# 4      2023
# ...     ...
# 50980  2013
# 50981  2013
# 50982  2013
# 50983  2013
# 50984  2013
#
# [50985 rows x 1 columns]

# %%
df.head(10)
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0  2023                     Level 1                99999       All industries
# 1  2023                     Level 1                99999       All industries
# 2  2023                     Level 1                99999       All industries
# 3  2023                     Level 1                99999       All industries
# 4  2023                     Level 1                99999       All industries
# 5  2023                     Level 1                99999       All industries
# 6  2023                     Level 1                99999       All industries
# 7  2023                     Level 1                99999       All industries
# 8  2023                     Level 1                99999       All industries
# 9  2023                     Level 1                99999       All industries
#
#                 Units Variable_code  \
# 0  Dollars (millions)           H01
# ...

# %%
df.tail(10)
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 50975  2013                     Level 3                 ZZ11
# 50976  2013                     Level 3                 ZZ11
# 50977  2013                     Level 3                 ZZ11
# 50978  2013                     Level 3                 ZZ11
# 50979  2013                     Level 3                 ZZ11
# 50980  2013                     Level 3                 ZZ11
# 50981  2013                     Level 3                 ZZ11
# 50982  2013                     Level 3                 ZZ11
# 50983  2013                     Level 3                 ZZ11
# 50984  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 50975  Food product manufacturing  Dollars (millions)           H32
# 50976  Food product manufacturing  Dollars (millions)           H33
# 50977  Food product manufacturing             Dollars           H34
# ...

# %%
df.columns
# Out:
# Index(['Year', 'Industry_aggregation_NZSIOC', 'Industry_code_NZSIOC',
#        'Industry_name_NZSIOC', 'Units', 'Variable_code', 'Variable_name',
#        'Variable_category', 'Value', 'Industry_code_ANZSIC06'],
#       dtype='object')

# %%
df[['Value']]
# Out:
#         Value
# 0      930995
# 1      821630
# 2       84354
# 3       25010
# 4      832964
# ...       ...
# 50980      52
# 50981      40
# 50982      12
# 50983       5
# 50984      46
#
# [50985 rows x 1 columns]

# %%
## slicing
df[['Value']][4:16]
# Out:
#      Value
# 4   832964
# 5    55267
# 6     7426
# 7    30814
# 8   147663
# 9      269
# 10    1639
# 11  566979
# 12   23176
# 13   80778
# 14   88197
# 15  105450

# %%
df[['Value']][2:5]
# Out:
#     Value
# 2   84354
# 3   25010
# 4  832964

# %%
df[['Variable_code' ]][4:5]
# Out:
#   Variable_code
# 4           H08

# %%
df[['Value']][1:5:2]## koi b value drop krne k liye.....syntax..[range:kaha tk: skip value]....
# Out:
#     Value
# 1  821630
# 3   25010
